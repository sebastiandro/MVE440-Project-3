# %%
import generate_data as gd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
X,Y = gd.gaussian_clusters(nr_features=3, nr_classes=10, nr_data_points=1000)
# Out:
# [[ 2.55681123  1.22206095 -0.29355943]
#  [ 0.43516813  0.82166324 -1.28925768]
#  [ 0.1498483  -1.82976941 -1.11307398]
#  [-0.67815504 -2.5006515  -0.31570978]
#  [ 1.99610237 -1.5278833  -3.41982438]
#  [ 0.18145591  1.05413076  1.0091418 ]
#  [ 0.49404285  0.29285282  2.21966013]
#  [ 2.07578041  1.67215636  3.50882098]
#  [-1.78733948  1.23901052 -4.7206155 ]
#  [-0.89760592 -0.12978096  5.02265636]]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = Axes3D(fig)

ax.scatter(X[:,0], X[:,1], X[:,2], c=Y)
plt.show()

# %%
X
